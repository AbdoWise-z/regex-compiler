# %%
from nfa import *
from RegexExpression import *
from IPython.display import display

# %%
expr = "[aA]bd(o|[ue]lrahman)"
text = "Abdo"
nfa = regex_to_nfa(expr)
dot = nfa.to_dot(expr)
display(dot)
print("Match string: ", text)
print("Match Result: ", nfa.match(text))
# Out:
# Match string:  Abdo
# Match Result:  True
